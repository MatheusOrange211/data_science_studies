# %%
import csv
import pandas as pd

# %%
arquivo = open("C:/Users/Usuario/Downloads/pedestrian-and-bicyclist-counts.csv")

rows = csv.reader(arquivo)

for row in rows:
    print(row)
# Out:
# ['Date', '7th and Park Campus', '7th underpass', '7th underpass Pedestrians', '7th underpass Cyclists', 'Bline Convention Cntr', 'Pedestrians', 'Cyclists', 'Jordan and 7th', 'N College and RR', 'S Walnut and Wylie']
# ['Wed, Feb 1, 2017', '186', '221', '155', '66', '688', '490', '198', '150', '14', '17']
# ['Thu, Feb 2, 2017', '194', '166', '98', '68', '676', '450', '226', '138', '10', '12']
# ['Fri, Feb 3, 2017', '147', '200', '142', '58', '603', '399', '204', '126', '11', '12']
# ['Sat, Feb 4, 2017', '58', '106', '39', '67', '747', '491', '256', '49', '17', '9']
# ['Sun, Feb 5, 2017', '73', '94', '43', '51', '905', '681', '224', '82', '17', '12']
# ['Mon, Feb 6, 2017', '191', '211', '140', '71', '782', '524', '258', '158', '10', '13']
# ['Tue, Feb 7, 2017', '171', '172', '109', '63', '714', '515', '199', '112', '5', '12']
# ['Wed, Feb 8, 2017', '194', '133', '79', '54', '613', '422', '191', '141', '6', '14']
# ...

# %%
pd.read_csv("C:/Users/Usuario/Downloads/pedestrian-and-bicyclist-counts.csv")
# Out:
#                   Date  7th and Park Campus  7th underpass  \
# 0     Wed, Feb 1, 2017                  186            221
# 1     Thu, Feb 2, 2017                  194            166
# 2     Fri, Feb 3, 2017                  147            200
# 3     Sat, Feb 4, 2017                   58            106
# 4     Sun, Feb 5, 2017                   73             94
# ..                 ...                  ...            ...
# 329  Wed, Dec 27, 2017                   12             21
# 330  Thu, Dec 28, 2017                   17             30
# 331  Fri, Dec 29, 2017                   11             28
# 332  Sat, Dec 30, 2017                    9             23
# 333  Sun, Dec 31, 2017                    2             24
#
#      7th underpass Pedestrians  7th underpass Cyclists  Bline Convention Cntr  \
# 0                          155                      66                    688
# 1                           98                      68                    676
# ...

# %%
pd.
